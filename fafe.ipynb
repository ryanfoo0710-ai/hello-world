# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanfoo0710-ai/hello-world/blob/main/fafe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com
# Out:
# Cloning into 'github.com'...
# fatal: repository 'https://github.com/' not found

# %%
# %cd https://github.com/ryanfoo0710-ai/hello-world#
# Out:
# [Errno 2] No such file or directory: 'https://github.com/ryanfoo0710-ai/hello-world#'
# /content
